# %% [markdown]
# # Starting metadata analysis

# %%
import pandas as pd
import numpy as np
from erddapy import ERDDAP

# %% [markdown]
# ### Load metadata table

# %%
e = ERDDAP(server="https://erddap.observations.voiceoftheocean.org/erddap", protocol='tabledap')

# %%
e.response = "csv"
e.dataset_id = "meta_users_table"
table = e.to_pandas()

# %%
table
# Out:
#     glider_serial  deployment_id  \
# 0          SEA068             27
# 1          SEA076              8
# 2          SEA076              9
# 3          SEA076             13
# 4          SEA076             16
# ..            ...            ...
# 166        SEA061             63
# 167        SEA078             11
# 168        SEA078             12
# 169        SEA078             14
# 170        SEA078             15
#
#                                              basin deployment_start (UTC)  \
# 0                            Eastern Gotland Basin   2022-07-27T00:00:00Z
# 1                                   Bornholm Basin   2022-10-05T00:00:00Z
# 2                                   Bornholm Basin   2022-10-20T00:00:00Z
# 3    Northern Baltic Proper, Eastern Gotland Basin   2023-01-13T00:00:00Z
# 4    Eastern Gotland Basin, Northern Baltic Proper   2023-04-11T00:00:00Z
# ..                                             ...                    ...
# 166                            Skagerrak, Kattegat   2022-08-15T00:00:00Z
# 167  Northern Baltic Proper, Eastern Gotland Basin   2023-03-16T00:00:00Z
# 168                          Eastern Gotland Basin   2023-05-16T00:00:00Z
# 169                          Western Gotland Basin   2023-07-28T00:00:00Z
# 170                          Western Gotland Basin   2023-10-06T00:00:00Z
#
#      deployment_end (UTC)                                available_variables  \
# 0    2022-07-31T00:00:00Z  ['profile_index', 'rowSize', 'latitude', 'long...
# 1    2022-10-19T00:00:00Z  ['profile_index', 'rowSize', 'latitude', 'long...
# 2    2022-10-31T00:00:00Z  ['profile_index', 'rowSize', 'latitude', 'long...
# 3    2023-02-14T00:00:00Z  ['profile_index', 'rowSize', 'latitude', 'long...
# 4    2023-05-16T00:00:00Z  ['profile_index', 'rowSize', 'latitude', 'long...
# ..                    ...                                                ...
# 166  2022-09-07T00:00:00Z  ['profile_index', 'rowSize', 'latitude', 'long...
# 167  2023-04-11T00:00:00Z  ['profile_index', 'rowSize', 'latitude', 'long...
# 168  2023-06-20T00:00:00Z  ['profile_index', 'rowSize', 'latitude', 'long...
# 169  2023-09-06T00:00:00Z  ['profile_index', 'rowSize', 'latitude', 'long...
# 170  2023-11-11T00:00:00Z  ['profile_index', 'rowSize', 'latitude', 'long...
#
#                                      science_variables  \
# 0    ['altimeter', 'backscatter_raw', 'backscatter_...
# 1    ['ad2cp_beam1_cell_number1', 'ad2cp_beam2_cell...
# 2    ['ad2cp_beam1_cell_number1', 'ad2cp_beam2_cell...
# 3    ['ad2cp_beam1_cell_number1', 'ad2cp_beam2_cell...
# 4    ['ad2cp_beam1_cell_number1', 'ad2cp_beam2_cell...
# ..                                                 ...
# 166  ['altimeter', 'backscatter_raw', 'backscatter_...
# 167  ['ad2cp_beam1_cell_number1', 'ad2cp_beam2_cell...
# 168  ['ad2cp_beam1_cell_number1', 'ad2cp_beam2_cell...
# 169  ['ad2cp_beam1_cell_number1', 'ad2cp_beam2_cell...
# 170  ['ad2cp_beam1_cell_number1', 'ad2cp_beam2_cell...
#
#                                                    ctd  \
# 0    {'calibration_date': '2021-06-17', 'factory_ca...
# 1    {'calibration_date': '2022-05-16', 'factory_ca...
# 2    {'calibration_date': '2022-05-16', 'factory_ca...
# 3    {'calibration_date': '2021-03-01', 'factory_ca...
# 4    {'calibration_date': '2021-03-01', 'factory_ca...
# ..                                                 ...
# 166  {'calibration_date': '2021-02-25', 'factory_ca...
# 167  {'calibration_date': '2022-10-24', 'factory_ca...
# 168  {'calibration_date': '2022-10-24', 'factory_ca...
# 169  {'calibration_date': '2022-10-24', 'factory_ca...
# 170  {'calibration_date': '2022-10-24', 'factory_ca...
#
#                                                 oxygen  \
# 0    {'calibration_date': '2021-06-17', 'factory_ca...
# 1    {'calibration_date': '2022-05-26', 'factory_ca...
# 2    {'calibration_date': '2022-05-26', 'factory_ca...
# 3    {'calibration_date': '2020-02-05', 'factory_ca...
# 4    {'calibration_date': '2022-11-08', 'factory_ca...
# ..                                                 ...
# 166  {'calibration_date': '2020-02-05', 'factory_ca...
# 167  {'calibration_date': '2022-11-11', 'factory_ca...
# 168  {'calibration_date': '2022-11-11', 'factory_ca...
# 169  {'calibration_date': '2022-11-08', 'factory_ca...
# 170  {'calibration_date': '2022-11-08', 'factory_ca...
#
#                                                 optics  \
# 0    {'calibration_date': '2022-05-10', 'calibratio...
# 1    {'calibration_date': '2022-04-04', 'calibratio...
# 2    {'calibration_date': '2022-04-04', 'calibratio...
# 3    {'calibration_date': '2022-04-04', 'calibratio...
# 4    {'calibration_date': '2022-04-04', 'calibratio...
# ..                                                 ...
# 166  {'calibration_date': '2021-03-23', 'calibratio...
# 167  {'calibration_date': '2022-10-05', 'calibratio...
# 168  {'calibration_date': '2022-10-05', 'calibratio...
# 169  {'calibration_date': '2022-10-05', 'calibratio...
# 170  {'calibration_date': '2022-10-05', 'calibratio...
#
#                                                  ad2cp irradiance  \
# 0                                                  NaN        NaN
# 1    {'calibration_date': '2022-03-16', 'factory_ca...        NaN
# 2    {'calibration_date': '2022-03-16', 'factory_ca...        NaN
# 3    {'calibration_date': '2022-03-16', 'factory_ca...        NaN
# 4    {'calibration_date': '2022-03-16', 'factory_ca...        NaN
# ..                                                 ...        ...
# 166                                                NaN        NaN
# 167  {'calibration_date': '2022-08-02', 'factory_ca...        NaN
# 168  {'calibration_date': '2022-08-02', 'factory_ca...        NaN
# 169  {'calibration_date': '2022-08-02', 'factory_ca...        NaN
# 170  {'calibration_date': '2022-08-02', 'factory_ca...        NaN
#
#                                                nitrate       datasetID
# 0                                                  NaN  nrt_SEA068_M27
# 1    {'calibration_date': '2019-05-20', 'factory_ca...   nrt_SEA076_M8
# 2    {'calibration_date': '2019-05-20', 'factory_ca...   nrt_SEA076_M9
# 3                                                  NaN  nrt_SEA076_M13
# 4                                                  NaN  nrt_SEA076_M16
# ..                                                 ...             ...
# 166                                                NaN  nrt_SEA061_M63
# 167                                                NaN  nrt_SEA078_M11
# 168                                                NaN  nrt_SEA078_M12
# 169                                                NaN  nrt_SEA078_M14
# 170                                                NaN  nrt_SEA078_M15
#
# [171 rows x 14 columns]

# %% [markdown]
# ### List of all possible science variables

# %%
sci_variables_all = []

for i, row in table.iterrows():
    sci_variables_all.extend(eval(row.science_variables[:]))

res = []
[res.append(x) for x in sci_variables_all if x not in res]

nav_var = {'profile_index', 'rowSize', 'latitude', 'longitude', 'time', 'depth',
           'angular_cmd', 'angular_pos', 'ballast_cmd', 'ballast_pos', 'desired_heading',
           'dive_num', 'heading', 'internal_pressure', 'internal_temperature', 'linear_cmd',
           'linear_pos', 'nav_state', 'pitch', 'profile_direction', 'profile_num',
           'roll', 'security_level', 'vertical_distance_to_seafloor', 'voltage', 'declination'}

res_sci = [i for i in res if i not in nav_var]

res_sci
# Out:
# ['altimeter',
#  'backscatter_raw',
#  'backscatter_scaled',
#  'cdom',
#  'cdom_qc',
#  'cdom_raw',
#  'cdom_raw_qc',
#  'chlorophyll',
#  'chlorophyll_qc',
#  'chlorophyll_raw',
#  'conductivity',
#  'conductivity_qc',
#  'density',
#  'density_qc',
#  'distance_over_ground',
#  'oxygen_concentration',
#  'oxygen_concentration_qc',
#  'oxygen_phase',
#  'particulate_backscatter',
#  'potential_density',
#  'potential_density_qc',
#  'potential_temperature',
#  'potential_temperature_qc',
#  'pressure',
#  'salinity',
#  'salinity_qc',
#  'temperature',
#  'temperature_oxygen',
#  'temperature_qc',
#  'ad2cp_beam1_cell_number1',
#  'ad2cp_beam2_cell_number1',
#  'ad2cp_beam3_cell_number1',
#  'ad2cp_beam4_cell_number1',
#  'ad2cp_heading',
#  'ad2cp_pitch',
#  'ad2cp_pressure',
#  'ad2cp_roll',
#  'ad2cp_time',
#  'nitrate_concentration',
#  'nitrate_molar_concentration',
#  'suna_internal_humidity',
#  'suna_internal_temperature',
#  'dead_reckoning',
#  'nav_resource',
#  'nanoflu_temperature',
#  'phycocyanin',
#  'phycocyanin_nanoflu',
#  'phycocyanin_raw',
#  'backscatter_raw_secondary',
#  'backscatter_scaled_secondary',
#  'chlorophyll_raw_secondary',
#  'chlorophyll_secondary',
#  'down_irradiance_380',
#  'down_irradiance_490',
#  'down_irradiance_532',
#  'downwelling_PAR',
#  'temperature_oxygen_qc',
#  'adcp_AccelerometerX',
#  'adcp_AccelerometerY',
#  'adcp_AccelerometerZ',
#  'adcp_Ambiguity',
#  'adcp_Heading',
#  'adcp_MagnetometerTemperature',
#  'adcp_MagnetometerX',
#  'adcp_MagnetometerY',
#  'adcp_MagnetometerZ',
#  'adcp_Pitch',
#  'adcp_Pressure',
#  'adcp_PressureSensorTemperature',
#  'adcp_RTCTemperature',
#  'adcp_Roll',
#  'adcp_SpeedOfSound',
#  'adcp_Status',
#  'adcp_TransmitEnergy',
#  'adcp_WaterTemperature',
#  'adcp_time',
#  'turbidity',
#  'turbidity_raw',
#  'internal_temperature_PAR',
#  'fdom',
#  'fdom_raw',
#  'methane_concentration',
#  'methane_raw_concentration',
#  'mets_raw_temperature',
#  'mets_temperature',
#  'oxygen_frequency',
#  'oxygen_frequency_qc']

# %% [markdown]
# ## Examples of query

# %% [markdown]
# ### Find all the mission where nitrate data was available

# %%
name = []
for i in range(len(table)):
    if 'nitrate_concentration' in table.science_variables[i]:
        name.append(f'{table.glider_serial[i]}_{table.deployment_id[i]}')
print(f"found {len(name)} datasets: {name}")
# Out:
# found 2 datasets: ['SEA076_8', 'SEA076_9']

# %% [markdown]
# ### Find all the mission with the FLBBPC optical sensor

# %%
name = []
for i in range(len(table)):
    if 'FLBBPC' in eval(table.optics[i])['model']:
        name.append(f'{table.glider_serial[i]}_{table.deployment_id[i]}')
print(f"found {len(name)} datasets: {name}")
# Out:
# found 88 datasets: ['SEA069_9', 'SEA069_11', 'SEA069_13', 'SEA069_15', 'SEA069_17', 'SEA069_19', 'SEA069_21', 'SEA055_18', 'SEA055_19', 'SEA055_20', 'SEA055_21', 'SEA055_23', 'SEA055_24', 'SEA055_26', 'SEA055_28', 'SEA055_31', 'SEA055_33', 'SEA055_35', 'SEA055_37', 'SEA055_39', 'SEA055_41', 'SEA055_43', 'SEA055_45', 'SEA055_46', 'SEA055_48', 'SEA055_50', 'SEA055_52', 'SEA055_53', 'SEA055_54', 'SEA055_56', 'SEA045_79', 'SEA063_55', 'SEA063_60', 'SEA044_28', 'SEA044_29', 'SEA044_32', 'SEA044_33', 'SEA044_34', 'SEA044_35', 'SEA044_40', 'SEA044_45', 'SEA044_46', 'SEA044_48', 'SEA044_72', 'SEA044_75', 'SEA044_77', 'SEA044_78', 'SEA044_79', 'SEA044_81', 'SEA044_83', 'SEA044_84', 'SEA044_85', 'SEA044_86', 'SEA067_15', 'SEA067_26', 'SEA067_27', 'SEA067_29', 'SEA067_30', 'SEA067_32', 'SEA067_37', 'SEA067_39', 'SEA067_41', 'SEA067_42', 'SEA067_44', 'SEA067_46', 'SEA067_51', 'SEA066_10', 'SEA066_12', 'SEA066_14', 'SEA066_16', 'SEA066_41', 'SEA066_42', 'SEA066_43', 'SEA066_45', 'SEA061_38', 'SEA061_39', 'SEA061_40', 'SEA061_42', 'SEA061_43', 'SEA061_45', 'SEA061_48', 'SEA061_50', 'SEA061_54', 'SEA061_56', 'SEA061_57', 'SEA061_60', 'SEA061_62', 'SEA061_63']

# %% [markdown]
# ### Find all Eastern Gotland mission in the period Jan 2022 - March 2023

# %%
name = []
for i in range(len(table)):
    if 'Eastern Gotland Basin' in table.basin[i]:
        if table['deployment_start (UTC)'][i] > '2022-01-01' and table['deployment_start (UTC)'][i] < '2023-03-01':
            name.append(f'{table.glider_serial[i]}_{table.deployment_id[i]}')
print(f"found {len(name)} datasets: {name}")
# Out:
# found 14 datasets: ['SEA068_27', 'SEA076_13', 'SEA069_9', 'SEA079_9', 'SEA067_26', 'SEA067_27', 'SEA067_29', 'SEA067_30', 'SEA067_32', 'SEA067_37', 'SEA067_39', 'SEA066_41', 'SEA066_42', 'SEA066_43']

# %% [markdown]
# ### Find all the mission with the oxygen sensor serial number 66

# %%
name = []
for i in range(len(table)):
    if '66' in eval(table.oxygen[i])['serial']:
        name.append(f'{table.glider_serial[i]}_{table.deployment_id[i]}')
print(f"found {len(name)} datasets: {name}")
# Out:
# found 6 datasets: ['SEA076_16', 'SEA076_17', 'SEA069_21', 'SEA077_21', 'SEA078_14', 'SEA078_15']

# %% [markdown]
# ### Find which brand this oxygen sensor is and what the calibration parameters are and where the mission was

# %%
oxy_tab = table.copy()
for i in range(len(oxy_tab)):
    if '66' not in eval(oxy_tab.oxygen[i])['serial']:
        oxy_tab.iloc[i] = np.nan
oxy_tab.dropna(how='all')
# Out:
#     glider_serial  deployment_id  \
# 4          SEA076           16.0
# 5          SEA076           17.0
# 14         SEA069           21.0
# 140        SEA077           21.0
# 169        SEA078           14.0
# 170        SEA078           15.0
#
#                                              basin deployment_start (UTC)  \
# 4    Eastern Gotland Basin, Northern Baltic Proper   2023-04-11T00:00:00Z
# 5                            Western Gotland Basin   2023-06-20T00:00:00Z
# 14                             Skagerrak, Kattegat   2023-11-17T00:00:00Z
# 140                          Eastern Gotland Basin   2023-03-16T00:00:00Z
# 169                          Western Gotland Basin   2023-07-28T00:00:00Z
# 170                          Western Gotland Basin   2023-10-06T00:00:00Z
#
#      deployment_end (UTC)                                available_variables  \
# 4    2023-05-16T00:00:00Z  ['profile_index', 'rowSize', 'latitude', 'long...
# 5    2023-07-28T00:00:00Z  ['profile_index', 'rowSize', 'latitude', 'long...
# 14   2023-11-30T00:00:00Z  ['profile_index', 'rowSize', 'latitude', 'long...
# 140  2023-04-11T00:00:00Z  ['profile_index', 'rowSize', 'latitude', 'long...
# 169  2023-09-06T00:00:00Z  ['profile_index', 'rowSize', 'latitude', 'long...
# 170  2023-11-11T00:00:00Z  ['profile_index', 'rowSize', 'latitude', 'long...
#
#                                      science_variables  \
# 4    ['ad2cp_beam1_cell_number1', 'ad2cp_beam2_cell...
# 5    ['ad2cp_beam1_cell_number1', 'ad2cp_beam2_cell...
# 14   ['altimeter', 'backscatter_raw', 'backscatter_...
# 140  ['ad2cp_beam1_cell_number1', 'ad2cp_beam2_cell...
# 169  ['ad2cp_beam1_cell_number1', 'ad2cp_beam2_cell...
# 170  ['ad2cp_beam1_cell_number1', 'ad2cp_beam2_cell...
#
#                                                    ctd  \
# 4    {'calibration_date': '2021-03-01', 'factory_ca...
# 5    {'calibration_date': '2021-03-01', 'factory_ca...
# 14   {'calibration_date': '2023-06-12', 'factory_ca...
# 140  {'calibration_date': '2022-05-17', 'factory_ca...
# 169  {'calibration_date': '2022-10-24', 'factory_ca...
# 170  {'calibration_date': '2022-10-24', 'factory_ca...
#
#                                                 oxygen  \
# 4    {'calibration_date': '2022-11-08', 'factory_ca...
# 5    {'calibration_date': '2022-11-08', 'factory_ca...
# 14   {'calibration_date': '2022-11-08', 'factory_ca...
# 140  {'calibration_date': '2022-11-08', 'factory_ca...
# 169  {'calibration_date': '2022-11-08', 'factory_ca...
# 170  {'calibration_date': '2022-11-08', 'factory_ca...
#
#                                                 optics  \
# 4    {'calibration_date': '2022-04-04', 'calibratio...
# 5    {'calibration_date': '2022-04-04', 'calibratio...
# 14   {'calibration_date': '2021-03-22', 'calibratio...
# 140  {'calibration_date': '2022-04-20', 'calibratio...
# 169  {'calibration_date': '2022-10-05', 'calibratio...
# 170  {'calibration_date': '2022-10-05', 'calibratio...
#
#                                                  ad2cp irradiance nitrate  \
# 4    {'calibration_date': '2022-03-16', 'factory_ca...        NaN     NaN
# 5    {'calibration_date': '2022-03-16', 'factory_ca...        NaN     NaN
# 14                                                 NaN        NaN     NaN
# 140  {'calibration_date': '2022-06-02', 'factory_ca...        NaN     NaN
# 169  {'calibration_date': '2022-08-02', 'factory_ca...        NaN     NaN
# 170  {'calibration_date': '2022-08-02', 'factory_ca...        NaN     NaN
#
#           datasetID
# 4    nrt_SEA076_M16
# 5    nrt_SEA076_M17
# 14   nrt_SEA069_M21
# 140  nrt_SEA077_M21
# 169  nrt_SEA078_M14
# 170  nrt_SEA078_M15

# %% [markdown]
# ### Find all types of optical sensors data available

# %%
opt_sens = []
for i, row in table.iterrows():
    opt_sens.append([eval(row.optics)['model'], eval(row.optics)['make']])

opt_sens_type = []
[opt_sens_type.append(x) for x in opt_sens if x not in opt_sens_type]

opt_sens_type
# Out:
# [['FLBBCD', 'Wetlabs'],
#  ['FLBBPC', 'Wetlabs'],
#  ['FLNTU', 'Wetlabs'],
#  ['SEAOWL', 'Seabird']]

# %%
#List all FLBBPC sensors and calibration data
FLBBPC_sens = []
for i, row in table.iterrows():
    if 'FLBBPC' in eval(row.optics)['model']:
        FLBBPC_sens.append([eval(row.optics)['serial'], eval(row.optics)['calibration_date']])

FLBBPC_sens_type = []
[FLBBPC_sens_type.append(x) for x in FLBBPC_sens if x not in FLBBPC_sens_type]

FLBBPC_sens_type
# Out:
# [['6756', '2021-03-23'],
#  ['6754', '2021-03-22'],
#  ['6598', '2020-12-22'],
#  ['6754', '2021-03-23'],
#  ['6597', '2020-12-22'],
#  ['6755', '2021-03-22'],
#  ['7313', '2022-01-11'],
#  ['6753', '2021-03-23']]
